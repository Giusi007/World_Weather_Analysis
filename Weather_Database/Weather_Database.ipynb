# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of 2,000 random latitude and longitude cobinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []

# Initiliaze coordinates list.
coordinates = list (lat_lngs)

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the requests library.
import requests

# %%
# Import the API Key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | birao
# Processing Record 2 of Set 1 | coquimbo
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | santa maria do suacui
# Processing Record 11 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | paamiut
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | vila velha
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | ayan
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | sooke
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | biak
# Processing Record 30 of Set 1 | puerto colombia
# Processing Record 31 of Set 1 | hambantota
# Processing Record 32 of Set 1 | vyborg
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | dimbokro
# Processing Record 35 of Set 1 | bonavista
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | northam
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | truro
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | mazamari
# Processing Record 44 of Set 1 | avdiyivka
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | tshikapa
# Processing Record 48 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 1 | cayenne
# Processing Record 50 of Set 1 | kabalo
# Processing Record 1 of Set 2 | flin flon
# Processing Record 2 of Set 2 | susangerd
# Processing Record 3 of Set 2 | santa maria
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | asau
# Processing Record 8 of Set 2 | grand gaube
# Processing Record 9 of Set 2 | grindavik
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | kavaratti
# Processing Record 15 of Set 2 | guinticgan
# Processing Record 16 of Set 2 | nampula
# Processing Record 17 of Set 2 | clonakilty
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | mayo
# Processing Record 20 of Set 2 | hirara
# Processing Record 21 of Set 2 | sayyan
# Processing Record 22 of Set 2 | sao gabriel da cachoeira
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | somerset
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | phatthalung
# Processing Record 31 of Set 2 | angoram
# Processing Record 32 of Set 2 | abu zabad
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | esil
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | vuktyl
# Processing Record 37 of Set 2 | lieksa
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | kapaa
# Processing Record 41 of Set 2 | skalnyy
# City not found. Skipping...
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | eyl
# Processing Record 44 of Set 2 | pasighat
# Processing Record 45 of Set 2 | hammerfest
# Processing Record 46 of Set 2 | nabire
# Processing Record 47 of Set 2 | port hardy
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | floro
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | saqqez
# Processing Record 4 of Set 3 | salalah
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | mataura
# Processing Record 7 of Set 3 | zhigalovo
# Processing Record 8 of Set 3 | sao joao da barra
# Processing Record 9 of Set 3 | columbus
# Processing Record 10 of Set 3 | puerto del rosario
# Processing Record 11 of Set 3 | porbandar
# Processing Record 12 of Set 3 | saldanha
# Processing Record 13 of Set 3 | berlevag
# Processing Record 14 of Set 3 | mehamn
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | kulhudhuffushi
# Processing Record 17 of Set 3 | mombasa
# Processing Record 18 of Set 3 | lappeenranta
# Processing Record 19 of Set 3 | dongsheng
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | moberly
# Processing Record 22 of Set 3 | verkhoyansk
# Processing Record 23 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 24 of Set 3 | zimmi
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | buenaventura
# Processing Record 29 of Set 3 | semey
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | bucerias
# Processing Record 32 of Set 3 | sur
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | karad
# Processing Record 35 of Set 3 | srandakan
# Processing Record 36 of Set 3 | tougan
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | isabela
# Processing Record 44 of Set 3 | navrongo
# Processing Record 45 of Set 3 | masvingo
# Processing Record 46 of Set 3 | richards bay
# Processing Record 47 of Set 3 | poya
# Processing Record 48 of Set 3 | ternate
# Processing Record 49 of Set 3 | westport
# Processing Record 50 of Set 3 | yulara
# Processing Record 1 of Set 4 | cumra
# Processing Record 2 of Set 4 | vostok
# Processing Record 3 of Set 4 | aklavik
# Processing Record 4 of Set 4 | alofi
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | kawalu
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | ancud
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | haifa
# Processing Record 11 of Set 4 | jinxiang
# Processing Record 12 of Set 4 | hovd
# Processing Record 13 of Set 4 | linxia
# Processing Record 14 of Set 4 | port lincoln
# Processing Record 15 of Set 4 | jardim
# Processing Record 16 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 4 | constitucion
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | pozo colorado
# Processing Record 21 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | caravelas
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | dunedin
# Processing Record 26 of Set 4 | muzhi
# Processing Record 27 of Set 4 | amapa
# Processing Record 28 of Set 4 | dinan
# Processing Record 29 of Set 4 | leshukonskoye
# Processing Record 30 of Set 4 | vaini
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | vao
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | muros
# Processing Record 36 of Set 4 | saint-augustin
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | matviyivka
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | shitanjing
# Processing Record 42 of Set 4 | cascais
# Processing Record 43 of Set 4 | morgan city
# Processing Record 44 of Set 4 | ulladulla
# Processing Record 45 of Set 4 | varna
# Processing Record 46 of Set 4 | tsaratanana
# Processing Record 47 of Set 4 | mecca
# Processing Record 48 of Set 4 | nambucca heads
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | rio grande
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | acapulco
# Processing Record 3 of Set 5 | camacha
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | odweyne
# Processing Record 6 of Set 5 | luderitz
# Processing Record 7 of Set 5 | gerash
# Processing Record 8 of Set 5 | rajbiraj
# Processing Record 9 of Set 5 | martapura
# Processing Record 10 of Set 5 | nara
# Processing Record 11 of Set 5 | hami
# Processing Record 12 of Set 5 | bunia
# Processing Record 13 of Set 5 | brownsville
# Processing Record 14 of Set 5 | midland
# Processing Record 15 of Set 5 | portland
# Processing Record 16 of Set 5 | raga
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | ottumwa
# Processing Record 19 of Set 5 | alvik
# Processing Record 20 of Set 5 | san quintin
# Processing Record 21 of Set 5 | byron bay
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | lebanon
# Processing Record 24 of Set 5 | marmora
# Processing Record 25 of Set 5 | punta de bombon
# Processing Record 26 of Set 5 | saint-georges
# Processing Record 27 of Set 5 | lloydminster
# Processing Record 28 of Set 5 | mitu
# Processing Record 29 of Set 5 | sandpoint
# Processing Record 30 of Set 5 | izumo
# Processing Record 31 of Set 5 | clifton springs
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | teruel
# Processing Record 34 of Set 5 | pak phanang
# Processing Record 35 of Set 5 | mulchen
# Processing Record 36 of Set 5 | sistranda
# Processing Record 37 of Set 5 | popondetta
# Processing Record 38 of Set 5 | beneditinos
# Processing Record 39 of Set 5 | minatitlan
# Processing Record 40 of Set 5 | maningrida
# Processing Record 41 of Set 5 | honiara
# Processing Record 42 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 5 | iracoubo
# Processing Record 44 of Set 5 | kerema
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | sabha
# Processing Record 47 of Set 5 | el reno
# Processing Record 48 of Set 5 | neepawa
# Processing Record 49 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 5 | obo
# Processing Record 1 of Set 6 | laguna
# Processing Record 2 of Set 6 | seybaplaya
# Processing Record 3 of Set 6 | phan thiet
# Processing Record 4 of Set 6 | diamantino
# Processing Record 5 of Set 6 | inirida
# Processing Record 6 of Set 6 | elko
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | matara
# Processing Record 9 of Set 6 | dannenberg
# Processing Record 10 of Set 6 | soe
# Processing Record 11 of Set 6 | canete
# Processing Record 12 of Set 6 | east london
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | luangwa
# Processing Record 16 of Set 6 | barrow
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | nizhniy kuranakh
# Processing Record 19 of Set 6 | kysyl-syr
# Processing Record 20 of Set 6 | roma
# Processing Record 21 of Set 6 | pochutla
# Processing Record 22 of Set 6 | sobolevo
# Processing Record 23 of Set 6 | xichang
# Processing Record 24 of Set 6 | mirnyy
# Processing Record 25 of Set 6 | labuhan
# Processing Record 26 of Set 6 | nyimba
# Processing Record 27 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 6 | angoche
# Processing Record 29 of Set 6 | yerbogachen
# Processing Record 30 of Set 6 | half moon bay
# Processing Record 31 of Set 6 | agadez
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | inongo
# Processing Record 34 of Set 6 | sitka
# Processing Record 35 of Set 6 | tiksi
# Processing Record 36 of Set 6 | gimli
# Processing Record 37 of Set 6 | chernyshevskiy
# Processing Record 38 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | biri
# Processing Record 40 of Set 6 | san andres
# Processing Record 41 of Set 6 | yook
# Processing Record 42 of Set 6 | pevek
# Processing Record 43 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | sioux lookout
# Processing Record 45 of Set 6 | bridlington
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | sakakah
# Processing Record 48 of Set 6 | santa vitoria do palmar
# Processing Record 49 of Set 6 | samarai
# Processing Record 50 of Set 6 | cabo san lucas
# Processing Record 1 of Set 7 | mattru
# Processing Record 2 of Set 7 | kashihara
# Processing Record 3 of Set 7 | los llanos de aridane
# Processing Record 4 of Set 7 | isangel
# Processing Record 5 of Set 7 | inhambane
# Processing Record 6 of Set 7 | council bluffs
# Processing Record 7 of Set 7 | kimbe
# Processing Record 8 of Set 7 | khandyga
# Processing Record 9 of Set 7 | pitimbu
# Processing Record 10 of Set 7 | tual
# Processing Record 11 of Set 7 | tazmalt
# Processing Record 12 of Set 7 | fairbanks
# Processing Record 13 of Set 7 | oistins
# Processing Record 14 of Set 7 | havre
# Processing Record 15 of Set 7 | la mana
# Processing Record 16 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 7 | husavik
# Processing Record 18 of Set 7 | ibra
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | basco
# Processing Record 21 of Set 7 | zastron
# Processing Record 22 of Set 7 | hede
# Processing Record 23 of Set 7 | xinqing
# Processing Record 24 of Set 7 | valdosta
# Processing Record 25 of Set 7 | buraydah
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | champerico
# Processing Record 28 of Set 7 | nueva gerona
# Processing Record 29 of Set 7 | seoul
# Processing Record 30 of Set 7 | mahebourg
# Processing Record 31 of Set 7 | natal
# Processing Record 32 of Set 7 | vardo
# Processing Record 33 of Set 7 | superior
# Processing Record 34 of Set 7 | tamandare
# Processing Record 35 of Set 7 | sisimiut
# Processing Record 36 of Set 7 | takoradi
# Processing Record 37 of Set 7 | oranjemund
# Processing Record 38 of Set 7 | atar
# Processing Record 39 of Set 7 | isla mujeres
# Processing Record 40 of Set 7 | xingtai
# Processing Record 41 of Set 7 | nazarovo
# Processing Record 42 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 7 | hai phong
# City not found. Skipping...
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | severo-yeniseyskiy
# Processing Record 46 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 7 | luz
# Processing Record 48 of Set 7 | mabopane
# Processing Record 49 of Set 7 | faanui
# Processing Record 50 of Set 7 | almora
# Processing Record 1 of Set 8 | surt
# Processing Record 2 of Set 8 | champua
# Processing Record 3 of Set 8 | comodoro rivadavia
# Processing Record 4 of Set 8 | chicama
# Processing Record 5 of Set 8 | saskylakh
# Processing Record 6 of Set 8 | doha
# Processing Record 7 of Set 8 | sanawad
# Processing Record 8 of Set 8 | ligayan
# Processing Record 9 of Set 8 | necochea
# Processing Record 10 of Set 8 | carutapera
# Processing Record 11 of Set 8 | muisne
# Processing Record 12 of Set 8 | dukat
# Processing Record 13 of Set 8 | el tigre
# Processing Record 14 of Set 8 | huarmey
# Processing Record 15 of Set 8 | paita
# Processing Record 16 of Set 8 | waipawa
# Processing Record 17 of Set 8 | ust-nera
# Processing Record 18 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 8 | karpathos
# Processing Record 20 of Set 8 | tocopilla
# Processing Record 21 of Set 8 | hamilton
# Processing Record 22 of Set 8 | kargat
# Processing Record 23 of Set 8 | hofn
# Processing Record 24 of Set 8 | duz
# City not found. Skipping...
# Processing Record 25 of Set 8 | haines junction
# Processing Record 26 of Set 8 | stornoway
# Processing Record 27 of Set 8 | esperance
# Processing Record 28 of Set 8 | tonantins
# Processing Record 29 of Set 8 | pilar
# Processing Record 30 of Set 8 | unity
# Processing Record 31 of Set 8 | egvekinot
# Processing Record 32 of Set 8 | bandarbeyla
# Processing Record 33 of Set 8 | noyabrsk
# Processing Record 34 of Set 8 | sakaiminato
# Processing Record 35 of Set 8 | cherskiy
# Processing Record 36 of Set 8 | kyren
# Processing Record 37 of Set 8 | terrace bay
# Processing Record 38 of Set 8 | juneau
# Processing Record 39 of Set 8 | aransas pass
# Processing Record 40 of Set 8 | vestmanna
# Processing Record 41 of Set 8 | luanda
# Processing Record 42 of Set 8 | vila do maio
# Processing Record 43 of Set 8 | gisenyi
# Processing Record 44 of Set 8 | santiago del estero
# Processing Record 45 of Set 8 | ostrovnoy
# Processing Record 46 of Set 8 | abha
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | burica
# City not found. Skipping...
# Processing Record 49 of Set 8 | lodwar
# Processing Record 50 of Set 8 | sola
# Processing Record 1 of Set 9 | gornopravdinsk
# Processing Record 2 of Set 9 | lewiston
# Processing Record 3 of Set 9 | teguldet
# Processing Record 4 of Set 9 | vredendal
# Processing Record 5 of Set 9 | mashhad
# Processing Record 6 of Set 9 | galle
# Processing Record 7 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 9 | nakamura
# Processing Record 9 of Set 9 | goroka
# Processing Record 10 of Set 9 | cap malheureux
# Processing Record 11 of Set 9 | moree
# Processing Record 12 of Set 9 | hibbing
# Processing Record 13 of Set 9 | kyabe
# Processing Record 14 of Set 9 | tancanhuitz
# Processing Record 15 of Set 9 | rio verde de mato grosso
# Processing Record 16 of Set 9 | katsuura
# Processing Record 17 of Set 9 | sorland
# Processing Record 18 of Set 9 | tuatapere
# Processing Record 19 of Set 9 | gazojak
# Processing Record 20 of Set 9 | saint-joseph
# Processing Record 21 of Set 9 | tsogni
# Processing Record 22 of Set 9 | romanovka
# Processing Record 23 of Set 9 | lodja
# Processing Record 24 of Set 9 | puli
# Processing Record 25 of Set 9 | zabid
# Processing Record 26 of Set 9 | moron
# Processing Record 27 of Set 9 | cabano
# Processing Record 28 of Set 9 | kachug
# Processing Record 29 of Set 9 | balkhash
# Processing Record 30 of Set 9 | faya
# Processing Record 31 of Set 9 | kajaani
# Processing Record 32 of Set 9 | yenagoa
# Processing Record 33 of Set 9 | bocholt
# Processing Record 34 of Set 9 | sao joao de pirabas
# Processing Record 35 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 9 | pisco
# Processing Record 37 of Set 9 | presidencia roque saenz pena
# Processing Record 38 of Set 9 | boende
# Processing Record 39 of Set 9 | emerald
# Processing Record 40 of Set 9 | perth
# Processing Record 41 of Set 9 | vallenar
# Processing Record 42 of Set 9 | humaita
# Processing Record 43 of Set 9 | andenes
# Processing Record 44 of Set 9 | valley city
# Processing Record 45 of Set 9 | yen bai
# Processing Record 46 of Set 9 | tilichiki
# Processing Record 47 of Set 9 | zimovniki
# Processing Record 48 of Set 9 | vinh
# Processing Record 49 of Set 9 | debre tabor
# Processing Record 50 of Set 9 | najran
# Processing Record 1 of Set 10 | naco
# Processing Record 2 of Set 10 | kiama
# Processing Record 3 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 4 of Set 10 | stykkisholmur
# Processing Record 5 of Set 10 | marshalltown
# Processing Record 6 of Set 10 | prudentopolis
# Processing Record 7 of Set 10 | nago
# Processing Record 8 of Set 10 | marshall
# Processing Record 9 of Set 10 | basoko
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | ust-maya
# Processing Record 12 of Set 10 | seminole
# Processing Record 13 of Set 10 | santa isabel
# Processing Record 14 of Set 10 | bo phloi
# Processing Record 15 of Set 10 | clarence town
# Processing Record 16 of Set 10 | lima
# Processing Record 17 of Set 10 | uruzgan
# Processing Record 18 of Set 10 | axim
# Processing Record 19 of Set 10 | cocobeach
# Processing Record 20 of Set 10 | songkhla
# Processing Record 21 of Set 10 | howard springs
# Processing Record 22 of Set 10 | cardston
# Processing Record 23 of Set 10 | thinadhoo
# Processing Record 24 of Set 10 | seinajoki
# Processing Record 25 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | krasnyy yar
# Processing Record 28 of Set 10 | boyabat
# Processing Record 29 of Set 10 | leeton
# Processing Record 30 of Set 10 | college
# Processing Record 31 of Set 10 | port moresby
# Processing Record 32 of Set 10 | mazagao
# Processing Record 33 of Set 10 | krasnoselkup
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | hue
# Processing Record 36 of Set 10 | obzor
# Processing Record 37 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 10 | manuk mangkaw
# Processing Record 39 of Set 10 | fort morgan
# Processing Record 40 of Set 10 | galveston
# Processing Record 41 of Set 10 | oussouye
# Processing Record 42 of Set 10 | dmitriyevskoye
# Processing Record 43 of Set 10 | asfi
# Processing Record 44 of Set 10 | hanzhong
# Processing Record 45 of Set 10 | the valley
# Processing Record 46 of Set 10 | flinders
# Processing Record 47 of Set 10 | praia da vitoria
# Processing Record 48 of Set 10 | san matias
# Processing Record 49 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 10 | walvis bay
# Processing Record 1 of Set 11 | kandrian
# Processing Record 2 of Set 11 | ler
# Processing Record 3 of Set 11 | shelburne
# Processing Record 4 of Set 11 | lardos
# Processing Record 5 of Set 11 | urengoy
# Processing Record 6 of Set 11 | ngunguru
# Processing Record 7 of Set 11 | koltubanovskiy
# Processing Record 8 of Set 11 | blairmore
# Processing Record 9 of Set 11 | sumbe
# Processing Record 10 of Set 11 | dix hills
# Processing Record 11 of Set 11 | gat
# Processing Record 12 of Set 11 | kijang
# Processing Record 13 of Set 11 | morbegno
# Processing Record 14 of Set 11 | mayor pablo lagerenza
# Processing Record 15 of Set 11 | chapais
# Processing Record 16 of Set 11 | yoichi
# Processing Record 17 of Set 11 | vaitape
# Processing Record 18 of Set 11 | colac
# Processing Record 19 of Set 11 | killybegs
# Processing Record 20 of Set 11 | ballarat
# Processing Record 21 of Set 11 | kamina
# Processing Record 22 of Set 11 | qorveh
# Processing Record 23 of Set 11 | hohhot
# Processing Record 24 of Set 11 | fowa
# Processing Record 25 of Set 11 | senneterre
# Processing Record 26 of Set 11 | itaueira
# Processing Record 27 of Set 11 | dingle
# Processing Record 28 of Set 11 | visnes
# Processing Record 29 of Set 11 | gbadolite
# Processing Record 30 of Set 11 | morant bay
# Processing Record 31 of Set 11 | price
# Processing Record 32 of Set 11 | araouane
# Processing Record 33 of Set 11 | pimenta bueno
# Processing Record 34 of Set 11 | chitrakonda
# Processing Record 35 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 36 of Set 11 | kirkuk
# Processing Record 37 of Set 11 | mitsamiouli
# Processing Record 38 of Set 11 | yumen
# Processing Record 39 of Set 11 | broken hill
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | zanjan
# Processing Record 42 of Set 11 | santiago
# Processing Record 43 of Set 11 | mabaruma
# Processing Record 44 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | jensen beach
# Processing Record 46 of Set 11 | tateyama
# Processing Record 47 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 48 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 49 of Set 11 | udachnyy
# Processing Record 50 of Set 11 | kruisfontein
# Processing Record 1 of Set 12 | ahuimanu
# Processing Record 2 of Set 12 | bilma
# Processing Record 3 of Set 12 | kavieng
# Processing Record 4 of Set 12 | afrikanda
# Processing Record 5 of Set 12 | mikumi
# Processing Record 6 of Set 12 | lovozero
# Processing Record 7 of Set 12 | bondo
# Processing Record 8 of Set 12 | doka
# Processing Record 9 of Set 12 | pacific grove
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | erenhot
# Processing Record 12 of Set 12 | manaure
# Processing Record 13 of Set 12 | selma
# Processing Record 14 of Set 12 | gap
# Processing Record 15 of Set 12 | bay roberts
# Processing Record 16 of Set 12 | xuddur
# Processing Record 17 of Set 12 | plettenberg bay
# Processing Record 18 of Set 12 | banjar
# Processing Record 19 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 12 | san cristobal
# Processing Record 21 of Set 12 | grimshaw
# Processing Record 22 of Set 12 | quatre cocos
# Processing Record 23 of Set 12 | carballo
# Processing Record 24 of Set 12 | la ronge
# Processing Record 25 of Set 12 | chepareria
# Processing Record 26 of Set 12 | nakhon phanom
# Processing Record 27 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 12 | luba
# Processing Record 29 of Set 12 | eureka
# Processing Record 30 of Set 12 | nelson bay
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | cururupu
# Processing Record 33 of Set 12 | baraki barak
# Processing Record 34 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 12 | olinda
# Processing Record 36 of Set 12 | mayahi
# Processing Record 37 of Set 12 | chumikan
# Processing Record 38 of Set 12 | svetlaya
# Processing Record 39 of Set 12 | jishou
# Processing Record 40 of Set 12 | alanya
# Processing Record 41 of Set 12 | sabang
# Processing Record 42 of Set 12 | chandla
# Processing Record 43 of Set 12 | budogoshch
# Processing Record 44 of Set 12 | niamey
# Processing Record 45 of Set 12 | alta floresta
# Processing Record 46 of Set 12 | deniliquin
# Processing Record 47 of Set 12 | albanel
# Processing Record 48 of Set 12 | roswell
# Processing Record 49 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 12 | grande prairie
# Processing Record 1 of Set 13 | jalu
# Processing Record 2 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 13 | kendari
# Processing Record 4 of Set 13 | sawtell
# Processing Record 5 of Set 13 | gemona
# Processing Record 6 of Set 13 | ambon
# Processing Record 7 of Set 13 | kampene
# Processing Record 8 of Set 13 | zeerust
# Processing Record 9 of Set 13 | sikeston
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | blaubeuren
# Processing Record 12 of Set 13 | xinpu
# Processing Record 13 of Set 13 | warnes
# Processing Record 14 of Set 13 | benghazi
# Processing Record 15 of Set 13 | moerai
# Processing Record 16 of Set 13 | maumere
# Processing Record 17 of Set 13 | douentza
# Processing Record 18 of Set 13 | ust-barguzin
# Processing Record 19 of Set 13 | canitas
# City not found. Skipping...
# Processing Record 20 of Set 13 | wairoa
# Processing Record 21 of Set 13 | matagami
# Processing Record 22 of Set 13 | guiratinga
# Processing Record 23 of Set 13 | neuquen
# Processing Record 24 of Set 13 | warri
# Processing Record 25 of Set 13 | williston
# Processing Record 26 of Set 13 | lasa
# Processing Record 27 of Set 13 | payo
# Processing Record 28 of Set 13 | kryve ozero
# Processing Record 29 of Set 13 | monrovia
# Processing Record 30 of Set 13 | tiarei
# Processing Record 31 of Set 13 | ust-omchug
# Processing Record 32 of Set 13 | coruripe
# Processing Record 33 of Set 13 | bonito
# Processing Record 34 of Set 13 | rapid valley
# Processing Record 35 of Set 13 | lincoln
# Processing Record 36 of Set 13 | acari
# Processing Record 37 of Set 13 | iskateley
# Processing Record 38 of Set 13 | matay
# Processing Record 39 of Set 13 | hokitika
# Processing Record 40 of Set 13 | kedgwick
# Processing Record 41 of Set 13 | touros
# Processing Record 42 of Set 13 | kloulklubed
# Processing Record 43 of Set 13 | kudahuvadhoo
# Processing Record 44 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 13 | bozoum
# Processing Record 46 of Set 13 | mizan teferi
# Processing Record 47 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 13 | marienburg
# Processing Record 49 of Set 13 | berdigestyakh
# Processing Record 50 of Set 13 | labuan
# Processing Record 1 of Set 14 | pahrump
# Processing Record 2 of Set 14 | barranca
# Processing Record 3 of Set 14 | ust-karsk
# Processing Record 4 of Set 14 | nyagan
# Processing Record 5 of Set 14 | presque isle
# Processing Record 6 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 14 | christchurch
# Processing Record 8 of Set 14 | las vegas
# Processing Record 9 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 10 of Set 14 | bam
# Processing Record 11 of Set 14 | santa rosa
# Processing Record 12 of Set 14 | plainview
# Processing Record 13 of Set 14 | tsarychanka
# Processing Record 14 of Set 14 | de aar
# Processing Record 15 of Set 14 | puerto baquerizo moreno
# Processing Record 16 of Set 14 | buchanan
# Processing Record 17 of Set 14 | kalmunai
# Processing Record 18 of Set 14 | dampit
# Processing Record 19 of Set 14 | marawi
# Processing Record 20 of Set 14 | morehead
# Processing Record 21 of Set 14 | aitape
# Processing Record 22 of Set 14 | hope
# Processing Record 23 of Set 14 | bullhead city
# Processing Record 24 of Set 14 | harper
# Processing Record 25 of Set 14 | ilhabela
# Processing Record 26 of Set 14 | samdrup jongkhar
# Processing Record 27 of Set 14 | high level
# Processing Record 28 of Set 14 | khani
# Processing Record 29 of Set 14 | stara zagora
# Processing Record 30 of Set 14 | okakarara
# Processing Record 31 of Set 14 | tairua
# Processing Record 32 of Set 14 | taoudenni
# Processing Record 33 of Set 14 | port keats
# Processing Record 34 of Set 14 | saryozek
# Processing Record 35 of Set 14 | whitianga
# Processing Record 36 of Set 14 | idanre
# Processing Record 37 of Set 14 | kahului
# Processing Record 38 of Set 14 | pontianak
# Processing Record 39 of Set 14 | marsabit
# Processing Record 40 of Set 14 | gao
# Processing Record 41 of Set 14 | kaeo
# Processing Record 42 of Set 14 | bang saphan
# Processing Record 43 of Set 14 | tougue
# Processing Record 44 of Set 14 | fuxin
# Processing Record 45 of Set 14 | christiana
# Processing Record 46 of Set 14 | ostersund
# Processing Record 47 of Set 14 | russell
# Processing Record 48 of Set 14 | bara
# Processing Record 49 of Set 14 | aguilas
# Processing Record 50 of Set 14 | humpolec
# Processing Record 1 of Set 15 | olafsvik
# Processing Record 2 of Set 15 | nishihara
# Processing Record 3 of Set 15 | lagos
# Processing Record 4 of Set 15 | bagdarin
# Processing Record 5 of Set 15 | prescott
# Processing Record 6 of Set 15 | cumpas
# Processing Record 7 of Set 15 | san carlos del zulia
# Processing Record 8 of Set 15 | san jeronimo
# Processing Record 9 of Set 15 | mackay
# Processing Record 10 of Set 15 | kathmandu
# Processing Record 11 of Set 15 | peniche
# Processing Record 12 of Set 15 | pinega
# Processing Record 13 of Set 15 | arica
# Processing Record 14 of Set 15 | mangai
# Processing Record 15 of Set 15 | zhigansk
# Processing Record 16 of Set 15 | loanda
# Processing Record 17 of Set 15 | anadyr
# Processing Record 18 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 15 | laramie
# Processing Record 20 of Set 15 | dolores
# Processing Record 21 of Set 15 | ukiah
# Processing Record 22 of Set 15 | shu
# Processing Record 23 of Set 15 | pervomayskoye
# Processing Record 24 of Set 15 | gravdal
# Processing Record 25 of Set 15 | tommot
# Processing Record 26 of Set 15 | port hedland
# Processing Record 27 of Set 15 | zhovtneve
# Processing Record 28 of Set 15 | trairi
# Processing Record 29 of Set 15 | broome
# Processing Record 30 of Set 15 | yeppoon
# Processing Record 31 of Set 15 | wasilla
# Processing Record 32 of Set 15 | moissala
# Processing Record 33 of Set 15 | murray bridge
# Processing Record 34 of Set 15 | avera
# Processing Record 35 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 15 | leh
# Processing Record 37 of Set 15 | fenoarivo
# Processing Record 38 of Set 15 | gallup
# Processing Record 39 of Set 15 | newberg
# Processing Record 40 of Set 15 | qui nhon
# Processing Record 41 of Set 15 | madanapalle
# Processing Record 42 of Set 15 | guantanamo
# Processing Record 43 of Set 15 | bugalagrande
# Processing Record 44 of Set 15 | magistralnyy
# Processing Record 45 of Set 15 | maragogi
# Processing Record 46 of Set 15 | labytnangi
# Processing Record 47 of Set 15 | foki
# Processing Record 48 of Set 15 | kidal
# Processing Record 49 of Set 15 | kieta
# Processing Record 50 of Set 15 | sal rei
# Processing Record 1 of Set 16 | mayya
# Processing Record 2 of Set 16 | menongue
# Processing Record 3 of Set 16 | balestrand
# Processing Record 4 of Set 16 | octeville
# Processing Record 5 of Set 16 | sebinkarahisar
# Processing Record 6 of Set 16 | beringovskiy
# Processing Record 7 of Set 16 | muromtsevo
# Processing Record 8 of Set 16 | lorut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Put the dity data into a DataFrame.
weatherpy_database_df = pd.DataFrame(city_data)
weatherpy_database_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                      Birao      CF  10.2849   22.7882     96.87        26
# 1                   Coquimbo      CL -29.9533  -71.3436     61.11        64
# 2                     Avarua      CK -21.2078 -159.7750     73.45        94
# 3  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     37.99       100
# 4                     Hobart      AU -42.8794  147.3294     49.26        80
# 5                    Ushuaia      AR -54.8000  -68.3000     51.42        76
# 6                     Bethel      US  41.3712  -73.4140     58.05        89
# 7      Santa Maria Do Suacui      BR -18.1903  -42.4142     74.19        22
# 8               Ponta Do Sol      PT  32.6667  -17.1000     72.12        82
# 9                    Paamiut      GL  61.9940  -49.6678     34.95        86
#
#    Cloudiness  Wind Speed          Current Description
# 0          91        2.04              overcast clouds
# 1          64        3.67                broken clouds
# 2          75        2.30                broken clouds
# 3         100        6.71  light intensity shower rain
# 4           8        6.91                    clear sky
# 5          20        2.30                   few clouds
# 6         100        6.91              overcast clouds
# 7         100        9.64              overcast clouds
# 8          95        2.62                   light rain
# 9          56        3.38                broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
weatherpy_database_df.to_csv(output_data_file, index_label="City_ID")
